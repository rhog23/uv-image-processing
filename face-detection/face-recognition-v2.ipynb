# %%
import re
import numpy as np
import pandas as pd
from joblib import dump
import matplotlib.pyplot as plt
from sklearn import neighbors, svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
df = pd.read_csv("facial-embeddings-v2.csv")
new_df = df[df['name'] != 'Yonathan']
new_df = new_df.drop(columns=['Unnamed: 0'])
new_df.head()
# Out:
#       name                                          embedding
# 0  Alvandy  [-0.007838250137865543, -0.012785508297383785,...
# 1  Alvandy  [-0.0014699185267090797, -0.017871785908937454...
# 2  Alvandy  [-0.019909091293811798, 0.00019082269864156842...
# 3  Alvandy  [0.0044821579940617085, -0.009107334539294243,...
# 4  Alvandy  [-0.01001010462641716, -0.01484997570514679, -...

# %%
new_df['name'] = new_df['name'].replace('Yonathan v2', 'Yonathan')
new_df.tail()
# Out:
#           name                                          embedding
# 1171  Yonathan  [-0.022470857948064804, 0.004938748199492693, ...
# 1172  Yonathan  [-0.014198222197592258, 0.0076897600665688515,...
# 1173  Yonathan  [-0.0011516802478581667, 0.006943192332983017,...
# 1174  Yonathan  [-0.01738688349723816, 0.0065376171842217445, ...
# 1175  Yonathan  [-0.011633556336164474, 0.0087768929079175, 0....

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df['embedding'], new_df['name'],
                                                    train_size=0.8, random_state=0)

# %%
X_train[0]
# Out:
# '[-0.007838250137865543, -0.012785508297383785, -0.006814184598624706, 0.013027326203882694, -0.014677109196782112, 0.01332330796867609, 0.007694844622164965, 0.00953088328242302, 0.009046420454978943, -0.0017847619019448757, 0.012507213279604912, -0.006487730890512466, -0.014589626342058182, -0.0008445628918707371, -0.015005047433078289, -0.004681738093495369, -0.02235920913517475, 0.0028181918896734715, -0.004294056911021471, -0.008919660933315754, -0.012862494215369225, -0.02185255102813244, 0.027530981227755547, -0.007437588181346655, 0.02878297120332718, 0.0168162751942873, -0.01958628185093403, 0.009995498694479465, -0.003541673067957163, -0.01064338069409132, 0.009514175355434418, -0.011260181665420532, 0.0062005724757909775, -0.015696629881858826, 0.01699112541973591, 0.02063131146132946, -0.0058859651908278465, 0.010132416151463985, 0.004311881028115749, -0.016397949308156967, -0.001905268058180809, -0.0008318001637235284, 0.01931281015276909, -0.0112710390239954, 0.005610893480479717, -0.009977529756724834, -0.022428341209888458, -0.002614952391013503, 0.0018333515617996454, 0.01322238240391016, 0.015672994777560234, -0.016009286046028137, 0.018741890788078308, 0.0003766631707549095, -0.0069144912995398045, 0.016949759796261787, -0.008284680545330048, 0.03271752595901489, -0.011116796173155308, -0.018447576090693474, 0.004434944596141577, 0.0019373476970940828, 0.0024217376485466957, 0.0005714497528970242, 0.009317194111645222, 0.013294843025505543, 0.0209436547011137, 0.020152725279331207, 0.012594546191394329, 0.006229058839380741, -0.0005965489544905722, -0.009713484905660152, 0.005127964075654745, 0.02858479879796505, -0.01531180553138256, 0.007071012631058693, -0.009903588332235813, 0.029820309951901436, 0.008031514473259449, -0.0063518560491502285, -0.008871028199791908, -0.02612517960369587, -0.008237195201218128, 0.03736024349927902, 0.027536310255527496, -0.011706378310918808, -0.005293728783726692, -3.7571298889815807e-06, -0.017453577369451523, -0.012892485596239567, 0.04408840462565422, -0.010146988555788994, 0.004557820502668619, -0.019420765340328217, 0.01787066087126732, 0.01265961118042469, 0.028407439589500427, -0.004148008767515421, 0.005250393413007259, -0.0013691866770386696, 0.006813370622694492, -0.005496731959283352, 0.01160429511219263, -0.006421707104891539, 0.0018278856296092272, -0.006733546499162912, 0.007984338328242302, 0.02564106695353985, -0.004188625141978264, 0.024079788476228714, 0.005115622654557228, 0.00800366047769785, -0.006379246711730957, -0.00214365147985518, 0.003567034611478448, -0.0008744739461690187, -0.011574619449675083, -0.014258443377912045, 0.0007975166663527489, 0.01365234237164259, -0.009930266998708248, 0.016437890008091927, 2.9007322154939175e-05, -0.009042938239872456, 0.017798887565732002, 0.022533252835273743, 0.004019773565232754, -0.02304724045097828, 0.011298058554530144, -0.0010458860779181123, -0.004296203143894672, -0.004155934788286686, -0.02056312933564186, -0.008074737153947353, 0.007520249579101801, 0.009551485069096088, 0.031422268599271774, -0.0187844131141901, -0.017290502786636353, -0.02588995173573494, -0.010653256438672543, 0.007314582820981741, -0.014162041246891022, 0.01635589823126793, 0.00800860021263361, 0.005702391732484102, 0.002702948171645403, 0.025197600945830345, -0.00989353284239769, -0.020640647038817406, -0.0001642601564526558, -0.000467926322016865, 0.0020474190823733807, -0.004686348605901003, -0.008742691949009895, 0.009484725072979927, 0.01894058659672737, -0.004257554188370705, -0.025499140843749046, 0.009376710280776024, -0.016144271939992905, 0.003129740012809634, -0.014336463995277882, -0.0007397658191621304, -0.014225742779672146, -0.008836206048727036, 0.007818001322448254, 0.0045934016816318035, 0.00481639476493001, -0.00041606335435062647, -0.008259182795882225, -0.0033254260197281837, -0.007013533264398575, 0.003585449419915676, -0.004146684892475605, -0.023582831025123596, -0.009119412861764431, 0.01689590886235237,  ...

# %%
print(type(X_train[0]))
X_train = [np.fromstring(x[1:], sep=",") for x in X_train]
X_test = [np.fromstring(x[1:], sep=",") for x in X_test]
print(type(X_train[0]))
print(type(X_test[0]))
# Out:
# <class 'str'>
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_31548\1965393634.py:2: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   X_train = [np.fromstring(x[1:], sep=",") for x in X_train]
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_31548\1965393634.py:3: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   X_test = [np.fromstring(x[1:], sep=",") for x in X_test]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(type(X_train[0]))
print(len(X_train[0]))
# Out:
# <class 'numpy.ndarray'>
# 512

# %%
# KNN
knn_clf = neighbors.KNeighborsClassifier(n_neighbors=3)
knn_clf.fit(X_train, y_train)
y_pred = knn_clf.predict(X_test)

print(f"Test set predictions: {accuracy_score(y_test, y_pred):.3%}")
# Compute precision and recall on test data
print("🎯Precision, Recall, and F1-Score \n", classification_report(y_test, y_pred, target_names=new_df['name'].unique(), digits=5))
# Out:
# Test set predictions: 96.429%
# 🎯Precision, Recall, and F1-Score
#                precision    recall  f1-score   support
#
#      Alvandy    1.00000   1.00000   1.00000        30
#         Gres    1.00000   0.95349   0.97619        43
#        Jacky    0.91892   1.00000   0.95775        34
#       Kelvin    1.00000   0.89130   0.94253        46
#     Yonathan    0.91489   1.00000   0.95556        43
#
#     accuracy                        0.96429       196
#    macro avg    0.96676   0.96896   0.96640       196
# weighted avg    0.96726   0.96429   0.96421       196

# %%
# KNN Confusion Matrix
cm = confusion_matrix(y_test, y_pred, labels=new_df['name'].unique())
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=new_df['name'].unique())
disp.plot()
plt.show()

# %%
# SVM
svm_clf = svm.SVC(random_state=0, probability=True)
svm_clf.fit(X_train, y_train)
y_pred = svm_clf.predict(X_test)

print(f"Test set predictions: {accuracy_score(y_test, y_pred):.3%}")
# Compute precision and recall on test data
print("🎯Precision, Recall, and F1-Score \n", classification_report(y_test, y_pred, target_names=new_df['name'].unique(), digits=5))
# Out:
# Test set predictions: 97.449%
# 🎯Precision, Recall, and F1-Score
#                precision    recall  f1-score   support
#
#      Alvandy    1.00000   1.00000   1.00000        30
#         Gres    1.00000   0.95349   0.97619        43
#        Jacky    1.00000   1.00000   1.00000        34
#       Kelvin    0.97778   0.95652   0.96703        46
#     Yonathan    0.91304   0.97674   0.94382        43
#
#     accuracy                        0.97449       196
#    macro avg    0.97816   0.97735   0.97741       196
# weighted avg    0.97571   0.97449   0.97471       196

# %%
# SVM Confusion Matrix
cm = confusion_matrix(y_test, y_pred, labels=new_df['name'].unique())
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=new_df['name'].unique())
disp.plot()
plt.show()

# %%
# Saving models
# KNN model
dump(knn_clf, "knn_classifier.joblib")

# SVM model
dump(svm_clf, "svm_classifier.joblib")
# Out:
# ['svm_classifier.joblib']
